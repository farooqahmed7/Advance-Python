# %% [markdown]
# ## Area

# %%
# 450
length = float(input('Enter the value of length:'))
breadth = float(input('Enter the value of breath:'))

area= length * breadth
print('The area of given field is ', area)

# %%
length = float(25)
breadth = float(10)
area= length * breadth
print('The Area is', area)
# Out:
# The Area is 250.0

# %% [markdown]
# ## Sum of First n Positive Numbers

# %%
n=25
sum_n = n*(n+1)/2
print('The sum of first',n,'Positive numbers is', sum_n)
# Out:
# The sum of first 25 Positive numbers is 325.0

# %%
letter = input("Enter the letter:")
if letter == 'a' or letter == 'e' or letter == 'i' or letter =='o' or letter=='u':
    print('Its a vowel')
else:
    print('Its a consonent')
# Out:
# Enter the letter:c
# Its a consonent

# %%
n_sides=int(input('Enter the number of sides:'))
name=""
if n_sides ==3:
    print(' Its a Triangle')
elif n_sides ==4:
    print('Its a Parallelogram')
elif n_sides==5:
    print('Its a Pentagon')
elif n_sides==6:
    print('Its a Hexagon')
else:
    print('Its none of Geometrical Figure')
# Out:
# Enter the number of sides:5
# Its a Pentagon

# %%
year = int(input('Enter a year:'))
if year% 4==0:
    print('Its a Leap year')
else:
    print('Its not a Leap year')
# Out:
# Enter a year:2022
# Its not a Leap year

# %%
class Student:
    def __init__(self, s_name, s_age, s_perct):
        self.s_name = s_name
        self.s_age=s_age
        self.s_perct=s_perct
    def Marks(self):
        Print('The Name of student is',s_name)
        print('The age of student is', s_age)
        print('The Percentage of Student is',s_perct)

# %%
std_1= Student('Amit', 25, 95)
std_2= Student('Ahmed',25,95)

# %%
print(std_1.s_perct)
# Out:
# 95

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# 6      46  female  33.440         1     no  southeast   8240.58960
# 7      37  female  27.740         3     no  northwest   7281.50560
# 8      37    male  29.830         2     no  northeast   6406.41070
# 9      60  female  25.840         0     no  northwest  28923.13692
# 10     25    male  26.220         0     no  northeast   2721.32080
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 12     23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.dropna(subset=['age','sex'], axis=0, how='all', inplace =True)

# %%
df.drop('children', axis=1, inplace=True)

# %%
df.rename(columns={'sex':'gender'}, inplace=True)

# %%
df
# Out:
#       age  gender     bmi smoker     region      charges
# 0      19  female  27.900    yes  southwest  16884.92400
# 1      18    male  33.770     no  southeast   1725.55230
# 2      28    male  33.000     no  southeast   4449.46200
# 3      33    male  22.705     no  northwest  21984.47061
# 4      32    male  28.880     no  northwest   3866.85520
# 5      31  female  25.740     no  southeast   3756.62160
# 6      46  female  33.440     no  southeast   8240.58960
# 7      37  female  27.740     no  northwest   7281.50560
# 8      37    male  29.830     no  northeast   6406.41070
# 9      60  female  25.840     no  northwest  28923.13692
# 10     25    male  26.220     no  northeast   2721.32080
# 11     62  female  26.290    yes  southeast  27808.72510
# 12     23    male  34.400     no  southwest   1826.84300
# 13     56  female  39.820     no  southeast  11090.71780
# 14     27    male  42.130    yes  southeast  39611.75770
# ...

# %%
df
# Out:
#       age  gender     bmi smoker     region      charges
# 0      19  female  27.900    yes  southwest  16884.92400
# 1      18    male  33.770     no  southeast   1725.55230
# 2      28    male  33.000     no  southeast   4449.46200
# 3      33    male  22.705     no  northwest  21984.47061
# 4      32    male  28.880     no  northwest   3866.85520
# 5      31  female  25.740     no  southeast   3756.62160
# 6      46  female  33.440     no  southeast   8240.58960
# 7      37  female  27.740     no  northwest   7281.50560
# 8      37    male  29.830     no  northeast   6406.41070
# 9      60  female  25.840     no  northwest  28923.13692
# 10     25    male  26.220     no  northeast   2721.32080
# 11     62  female  26.290    yes  southeast  27808.72510
# 12     23    male  34.400     no  southwest   1826.84300
# 13     56  female  39.820     no  southeast  11090.71780
# 14     27    male  42.130    yes  southeast  39611.75770
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
plt.figure(figsize=(10,8))
sb.heatmap(df.corr(),annot=True, fmt='.0%')

# %%
from scipy import stats

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df.gender=le.fit_transform(df.gender)
df.region=le.fit_transform(df.region)
df.smoker=le.fit_transform(df.smoker)

# %%
df
# Out:
#       age  gender     bmi  smoker  region      charges
# 0      19       0  27.900       1       3  16884.92400
# 1      18       1  33.770       0       2   1725.55230
# 2      28       1  33.000       0       2   4449.46200
# 3      33       1  22.705       0       1  21984.47061
# 4      32       1  28.880       0       1   3866.85520
# 5      31       0  25.740       0       2   3756.62160
# 6      46       0  33.440       0       2   8240.58960
# 7      37       0  27.740       0       1   7281.50560
# 8      37       1  29.830       0       0   6406.41070
# 9      60       0  25.840       0       1  28923.13692
# 10     25       1  26.220       0       0   2721.32080
# 11     62       0  26.290       1       2  27808.72510
# 12     23       1  34.400       0       3   1826.84300
# 13     56       0  39.820       0       2  11090.71780
# 14     27       1  42.130       1       2  39611.75770
# 15     19       1  24.600       0       3   1837.23700
# ...
